# %%
# %cd ../
# Out:
# /home/jcx/Python/QAStatsV3

# %%
# %matplotlib inline
import qastats
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/jcx/.conda/envs/crypto/lib/python3.13/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
data = pd.read_pickle('examples/diario_normal.pickle')
data['bench'] = np.random.choice(data['Close'],len(data))

# %%
data.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stats = qastats.stats.get_daily_stats(data)
stats
# Out:
#                                 Close
# AuM                      000.000.000$
# Start                      2002-07-30
# End                        2023-01-27
# Period                           5161
# Total Return                   361.68
# Factor Return                  245.32
# Ret Corr with Factor              0.0
# Ret Corr with Factor +           0.01
# Ret Corr with Factor -           0.02
# CAGR                             4.42
# Annualized Vol                   9.94
# Max DD                         -21.58
# Calmar Ratio                      0.2
# Sortino Ratio                     1.0
# SQN                              3.08
# Omega Ratio                      1.18
# Skew                             0.03
# Kurt                             6.73
# VaR                              -1.0
# CVaR                            -1.58
# Stability                        0.97
# Riesgo Cola                      1.03
# WinRate                          0.54
# Avg ret                          0.05
# Best Day                         5.17
# Worst Day                       -5.05
# Avg Good Day                     0.67
# Avg Bad Day                     -0.67
# Max consecutive wins               11
# Max consecutive losses              6
# Outlier win ratio                8.23
# Outlier loose ratio              2.82
# Profit Factor                    1.18
# CPC Idx                          0.63
# Expectancy                       0.02
# Alpha                            0.07
# Alpha con Modelo +              -0.03
# Alpha con Moldelo -             -0.02
# Beta                            -0.01
# Beta con Modelo +                0.11
# Beta con Modelo -               -0.02
# Beta Fragility                   0.38
# Capture con Modelo +             0.01
# Capture con Modelo -            -0.01
# QA Alpha Capture                -0.69

# %%
dds = qastats.stats.get_drawdown_stats(data['Close'])

# %%
dds
# Out:
#                                         N       Std         X       min  \
# Lehman                               42.0  0.463817  0.087480 -0.956503
# US downgrade/European Debt Crisis    21.0  2.133897  0.196796 -5.045017
# Fukushima                            23.0  0.000000  0.000000  0.000000
# US Housing                           22.0  0.566476  0.086295 -1.919752
# EZB IR Event                         22.0  0.000000  0.000000  0.000000
# Aug07                                23.0  0.498187  0.078259 -1.215328
# Mar08                                20.0  0.000000  0.000000  0.000000
# Sept08                               21.0  0.203053  0.044310  0.000000
# 2009Q1                               39.0  1.117862 -0.240194 -3.158909
# 2009Q2                               63.0  0.752020 -0.045994 -2.514937
# Flash Crash                           3.0  2.177803  0.809279 -1.250150
# Apr14                                21.0  0.000000  0.000000  0.000000
# Oct14                                23.0  0.000000  0.000000  0.000000
# Fall2015                             31.0  0.587736 -0.041934 -1.930340
# Low Volatility Bull Market          648.0  0.383934  0.021964 -1.791618
# GFC Crash                           420.0  0.693735  0.045719 -3.158909
# Recovery                            945.0  0.791205  0.043888 -5.045017
# New Normal                         1441.0  0.573618  0.008849 -4.243185
# Taper Tantrum                        90.0  0.911571 -0.121330 -3.408780
# Brexit Referendum                   133.0  0.743071 -0.032555 -4.243185
# Brexit Process                      947.0  0.502270  0.030271 -2.195436
# US-China Trade War                  384.0  0.482978  0.048015 -1.811867
# Covid                               747.0  0.730767  0.019203 -3.137906
# GameStop Short Squeeze               18.0  0.550897  0.041971 -0.936769
# Post-Covid Recovery                 212.0  0.934868  0.019447 -3.137906
# Fed Rate Hikes                      219.0  0.985873  0.042493 -3.137906
# Russia-Ukraine War                  233.0  0.955717  0.039939 -3.137906
# Inflation Crisis                    269.0  0.920343  0.028683 -3.137906
# Crypto Crash 2022                   147.0  1.090881  0.001311 -3.137906
# AI Boom                              40.0  0.966886  0.227827 -1.655003
#
#                                         max
# Lehman                             1.628206
# US downgrade/European Debt Crisis  3.156773
# Fukushima                          0.000000
# US Housing                         0.745723
# EZB IR Event                       0.000000
# Aug07                              1.031867
# Mar08                              0.000000
# Sept08                             0.930507
# 2009Q1                             2.351296
# 2009Q2                             2.581617
# Flash Crash                        3.088750
# Apr14                              0.000000
# Oct14                              0.000000
# Fall2015                           1.009967
# Low Volatility Bull Market         1.694875
# GFC Crash                          5.166181
# Recovery                           3.558148
# New Normal                         2.684774
# Taper Tantrum                      1.581323
# Brexit Referendum                  2.684774
# Brexit Process                     2.252958
# US-China Trade War                 2.252958
# Covid                              3.847379
# GameStop Short Squeeze             1.178566
# Post-Covid Recovery                3.847379
# Fed Rate Hikes                     3.847379
# Russia-Ukraine War                 3.847379
# Inflation Crisis                   3.847379
# Crypto Crash 2022                  3.847379
# AI Boom                            3.194581

# %%
qastats.stats.show_worst_drawdown_periods(data['Close'])
# Out:
#   Net drawdown in %  Peak date Valley date Recovery date Duration
# 0         21.584419 2012-11-14  2013-11-20    2015-08-11      714
# 1         17.245491 2009-01-02  2009-06-10    2010-05-21      360
# 2         15.687742 2003-06-13  2003-08-13    2005-06-07      518
# 3          11.93748 2016-07-08  2017-05-10    2019-05-30      755
# 4         11.803891 2022-08-01  2022-11-07    2022-12-01       89

# %%
qastats.stats.var_usd(data['Close'])
# Out:
# np.float64(10028.09038253699)

# %%
qastats.stats.get_vami_diario(data['Close'])
# Out:
# OK
#                                   VAMI
# Date
# 2002-07-30 04:00:00+00:00         1000
# 2002-07-31 04:00:00+00:00  1000.123895
# 2002-08-01 04:00:00+00:00  1000.180847
# 2002-08-02 04:00:00+00:00  1000.283278
# 2002-08-05 04:00:00+00:00   1000.32741
# ...                                ...
# 2023-01-23 05:00:00+00:00  1013.857044
# 2023-01-24 05:00:00+00:00   1014.00284
# 2023-01-25 05:00:00+00:00  1014.027429
# 2023-01-26 05:00:00+00:00  1013.980257
# 2023-01-27 05:00:00+00:00  1013.954665
#
# [5161 rows x 1 columns]

# %%
qastats.reports.create_return_dd(data)
# Out:
# <h4> [JCX] - QUANTARMY </h4>
#    index  Performance  Max Drawdown
# 0     1%       -16.94        -20.63
# 1     5%        -8.70        -16.82
# 2    20%        -0.99        -12.04
# 3    30%         2.58        -10.86
# 4    40%         5.69         -9.66
# 5    50%         8.73         -8.75
# 6    60%        11.60         -8.09
# 7    70%        15.43         -7.37
# 8    80%        19.01         -6.56
# 9    90%        23.41         -5.71
# 10   95%        29.15         -4.87
# 11   99%        36.61         -4.00
